# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
COUNTRY_PATH = "../noah_example/Country_Profiles_Clean.csv"
#MEDAL_PATH = "../noah_example/Datasets/Olympic_Medal_Tally_History.csv"
EVENT_PATH = "../noah_example/Datasets/Olympic_Athlete_Event_Details.csv"
CURRENT_YEAR = 2024
OLDEST_YEAR_OF_INTEREST = CURRENT_YEAR - 20
MEDAL_TYPES = ('Gold', 'Silver', 'Bronze')

# %%
# read it in:
country_df= pd.read_csv(COUNTRY_PATH).drop(index=234)
print(country_df.shape)
country_df.head()
# Out:
# (234, 2)
#    noc         country
# 0  AFG     Afghanistan
# 1  ALB         Albania
# 2  ALG         Algeria
# 3  ASA  American Samoa
# 4  AND         Andorra

# %%
dup_both_mask_s = country_df.duplicated(keep=False)
print(dup_both_mask_s.sum())
dup_noc_mask_s = country_df.duplicated(subset='noc', keep=False)
print(dup_noc_mask_s.sum())
dup_country_mask_s = country_df.duplicated(subset='country', keep=False)
country_df[dup_country_mask_s].sort_values("country")
# Out:
# 0
# 0
#      noc             country
# 10   ANZ           Australia
# 11   AUS           Australia
# 23   BOH             Czechia
# 52   CZE             Czechia
# 60   GDR             Germany
# 75   GER             Germany
# 228  FRG             Germany
# 173  SAA             Germany
# 54   PRK   Republic of Korea
# 166  KOR   Republic of Korea
# 216  EUN  Russian Federation
# 194  URS  Russian Federation
# 171  RUS  Russian Federation
# 169  ROC  Russian Federation
# 181  SRB              Serbia
# 182  SCG              Serbia
# 192  VNM             Vietnam
# 227  VIE             Vietnam
# 193  YMD               Yemen
# 149  YAR               Yemen
# 230  YEM               Yemen
# 168  RHO            Zimbabwe
# 233  ZIM            Zimbabwe

# %%
dup_both_mask_s.sum()
# Out:
# 0

# %%
dup_country_mask_s.sum()
# Out:
# 23

# %%
# medal_df= pd.read_csv(MEDAL_PATH).rename(columns = {"country_noc" : "noc"})
# print(medal_df.shape)
# medal_df.head()

# %%
#medal_df.info()

# %%
#medal_df.describe()

# %%
# #merge the 2 datasets: country and game sum
# country_medal_df = pd.merge(country_df, medal_df, on="country")
# print(country_medal_df.shape)
# country_medal_df.head()

# %%
# noc_mismatch_mask_s = country_medal_df.noc_x != country_medal_df.noc_y
# country_medal_df[noc_mismatch_mask_s]

# %%
#country_medal_df.loc[noc_mismatch_mask_s, "country"].unique()

# %%
#Country_medal_df = Country_medal_df.rename(columns = {"noc_x" : "noc"})
#Country_medal_df.head()

# %%
event_df= pd.read_csv(EVENT_PATH)\
.dropna()\
.rename(columns = {"country_noc" : "noc"})

event_df[['year', 'season']] = event_df['edition'].str.split(' ', n=1, expand=True)
event_df['year'] = event_df['year'].astype(int)

print(event_df.info())
print(event_df.shape)
event_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44687 entries, 20 to 316816
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   edition      44687 non-null  object
#  1   edition_id   44687 non-null  int64
#  2   noc          44687 non-null  object
#  3   sport        44687 non-null  object
#  4   event        44687 non-null  object
#  5   result_id    44687 non-null  int64
#  6   athlete      44687 non-null  object
#  7   athlete_id   44687 non-null  int64
#  8   pos          44687 non-null  object
#  9   medal        44687 non-null  object
#  10  isTeamSport  44687 non-null  bool
#  11  year         44687 non-null  int64
#  12  season       44687 non-null  object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 4.5+ MB
# None
# (44687, 13)
#                  edition  edition_id  noc      sport  \
# 20  1908 Summer Olympics           5  ANZ  Athletics
# 30  1908 Summer Olympics           5  ANZ     Boxing
# 32  1908 Summer Olympics           5  ANZ      Rugby
# 33  1908 Summer Olympics           5  ANZ      Rugby
# 34  1908 Summer Olympics           5  ANZ      Rugby
#
#                           event  result_id          athlete  athlete_id pos  \
# 20  3,500 metres Race Walk, Men      56421       Harry Kerr       64719   3
# 30            Middleweight, Men      21263      Snowy Baker       45153   2
# 32                   Rugby, Men      31505     John Barnett       11237   1
# 33                   Rugby, Men      31505  Phil Carmichael       11239   1
# 34                   Rugby, Men      31505      Dan Carroll       11240   1
#
#      medal  isTeamSport  year           season
# 20  Bronze        False  1908  Summer Olympics
# 30  Silver        False  1908  Summer Olympics
# 32    Gold         True  1908  Summer Olympics
# 33    Gold         True  1908  Summer Olympics
# 34    Gold         True  1908  Summer Olympics

# %%
#merge country medal with olympic athlete event to extract gender
country_event_df = pd.merge(event_df, country_df, on="noc", how="left")
country_event_df.info()
print(country_event_df.shape)
country_event_df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44687 entries, 0 to 44686
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   edition      44687 non-null  object
#  1   edition_id   44687 non-null  int64
#  2   noc          44687 non-null  object
#  3   sport        44687 non-null  object
#  4   event        44687 non-null  object
#  5   result_id    44687 non-null  int64
#  6   athlete      44687 non-null  object
#  7   athlete_id   44687 non-null  int64
#  8   pos          44687 non-null  object
#  9   medal        44687 non-null  object
#  10  isTeamSport  44687 non-null  bool
#  11  year         44687 non-null  int64
#  12  season       44687 non-null  object
#  13  country      44687 non-null  object
# dtypes: bool(1), int64(4), object(9)
# memory usage: 4.5+ MB
# (44687, 14)
#                     edition  edition_id  noc          sport  \
# 44682  2022 Winter Olympics          62  USA  Speed Skating
# 44683  2022 Winter Olympics          62  USA  Speed Skating
# 44684  2022 Winter Olympics          62  USA      Bobsleigh
# 44685  2022 Winter Olympics          62  USA      Bobsleigh
# 44686  2022 Winter Olympics          62  CAN      Bobsleigh
#
#                      event  result_id              athlete  athlete_id pos  \
# 44682    500 metres, Women   19020424         Erin Jackson      138378   1
# 44683  1,000 metres, Women   19020425        Brittany Bowe      128778   3
# 44684       Monobob, Women   19019671    Kaillie Humphries      118672   1
# 44685       Monobob, Women   19019671  Elana Meyers Taylor      118644   2
# 44686       Monobob, Women   19019671   Christine de Bruin      136825   3
#
#         medal  isTeamSport  year           season        country
# 44682    Gold        False  2022  Winter Olympics  United States
# 44683  Bronze        False  2022  Winter Olympics  United States
# 44684    Gold        False  2022  Winter Olympics  United States
# 44685  Silver        False  2022  Winter Olympics  United States
# 44686  Bronze        False  2022  Winter Olympics         Canada

# %%
#I want to filter for up to 20years:
year_mask_s = country_event_df["year"] >= OLDEST_YEAR_OF_INTEREST 
country_event_recent_df = country_event_df[year_mask_s]
print(country_event_recent_df.shape)
country_event_recent_df.head()
# Out:
# (13697, 14)
#                  edition  edition_id  noc      sport  \
# 55  2012 Summer Olympics          54  BRN  Athletics
# 56  2016 Summer Olympics          59  BRN  Athletics
# 57  2016 Summer Olympics          59  BRN  Athletics
# 58  2020 Summer Olympics          61  BRN  Athletics
# 60  2008 Summer Olympics          53  AFG  Taekwondo
#
#                                event  result_id             athlete  \
# 55               1,500 metres, Women     302391        Maryam Jamal
# 56                   Marathon, Women     359066        Eunice Kirwa
# 57  3,000 metres Steeplechase, Women     359093          Ruth Jebet
# 58              10,000 metres, Women   19000739  Kalkidan Gezahegne
# 60                    Flyweight, Men     262097     Rohullah Nikpai
#
#     athlete_id pos   medal  isTeamSport  year           season      country
# 55      115219   1    Gold        False  2012  Summer Olympics      Bahrain
# 56      129369   2  Silver        False  2016  Summer Olympics      Bahrain
# 57      129374   1    Gold        False  2016  Summer Olympics      Bahrain
# 58      141289   2  Silver        False  2020  Summer Olympics      Bahrain
# 60      117410  =3  Bronze        False  2008  Summer Olympics  Afghanistan

# %%
#country_event_recent_df.sort_values("year")

# %%
#look for gold wins: female, last 10 years and top 10 countries
#olympic athlete event to seperate columns
# Split the 'Event' column into 'Event' and 'Gender' columns
country_event_recent_df[['Event', 'Gender']] = country_event_recent_df['event'].str.extract(r'(.*), (\w+)')
print(country_event_recent_df.info())
print(country_event_recent_df.shape)
country_event_recent_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13697 entries, 55 to 44686
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   edition      13697 non-null  object
#  1   edition_id   13697 non-null  int64
#  2   noc          13697 non-null  object
#  3   sport        13697 non-null  object
#  4   event        13697 non-null  object
#  5   result_id    13697 non-null  int64
#  6   athlete      13697 non-null  object
#  7   athlete_id   13697 non-null  int64
#  8   pos          13697 non-null  object
#  9   medal        13697 non-null  object
#  10  isTeamSport  13697 non-null  bool
#  11  year         13697 non-null  int64
#  12  season       13697 non-null  object
#  13  country      13697 non-null  object
#  14  Event        13697 non-null  object
#  15  Gender       13697 non-null  object
# dtypes: bool(1), int64(4), object(11)
# memory usage: 1.7+ MB
# None
# (13697, 16)
# /var/folders/t3/shypb4d90rggs0g7t37cwckc0000gn/T/ipykernel_23513/3749828534.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_event_recent_df[['Event', 'Gender']] = country_event_recent_df['event'].str.extract(r'(.*), (\w+)')
# /var/folders/t3/shypb4d90rggs0g7t37cwckc0000gn/T/ipykernel_23513/3749828534.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_event_recent_df[['Event', 'Gender']] = country_event_recent_df['event'].str.extract(r'(.*), (\w+)')
#                  edition  edition_id  noc      sport  \
# 55  2012 Summer Olympics          54  BRN  Athletics
# 56  2016 Summer Olympics          59  BRN  Athletics
# 57  2016 Summer Olympics          59  BRN  Athletics
# 58  2020 Summer Olympics          61  BRN  Athletics
# 60  2008 Summer Olympics          53  AFG  Taekwondo
# 61  2012 Summer Olympics          54  AFG  Taekwondo
# 66  2004 Summer Olympics          26  AZE     Boxing
# 67  2004 Summer Olympics          26  AZE     Boxing
# 68  2004 Summer Olympics          26  AZE   Shooting
# 69  2004 Summer Olympics          26  AZE   Shooting
#
#                                 event  result_id                 athlete  \
# 55                1,500 metres, Women     302391            Maryam Jamal
# 56                    Marathon, Women     359066            Eunice Kirwa
# 57   3,000 metres Steeplechase, Women     359093              Ruth Jebet
# 58               10,000 metres, Women   19000739      Kalkidan Gezahegne
# 60                     Flyweight, Men     262097         Rohullah Nikpai
# 61                 Featherweight, Men     325026         Rohullah Nikpai
# 66                     Flyweight, Men      27411            Fuad Aslanov
# 67                  Bantamweight, Men      27447          Ağası Məmmədov
# 68  Sporting Pistol, 25 metres, Women      52023           İradə Aşumova
# 69                       Skeet, Women      52043  Zemfira Meftaxetdinova
#
#     athlete_id pos   medal  isTeamSport  year           season      country  \
# 55      115219   1    Gold        False  2012  Summer Olympics      Bahrain
# 56      129369   2  Silver        False  2016  Summer Olympics      Bahrain
# 57      129374   1    Gold        False  2016  Summer Olympics      Bahrain
# 58      141289   2  Silver        False  2020  Summer Olympics      Bahrain
# 60      117410  =3  Bronze        False  2008  Summer Olympics  Afghanistan
# 61      117410  =3  Bronze        False  2012  Summer Olympics  Afghanistan
# 66      106167  =3  Bronze        False  2004  Summer Olympics   Azerbaijan
# 67       90027  =3  Bronze        False  2004  Summer Olympics   Azerbaijan
# 68       41255   3  Bronze        False  2004  Summer Olympics   Azerbaijan
# 69       93007   3  Bronze        False  2004  Summer Olympics   Azerbaijan
#
#                          Event Gender
# 55                1,500 metres  Women
# 56                    Marathon  Women
# 57   3,000 metres Steeplechase  Women
# 58               10,000 metres  Women
# 60                   Flyweight    Men
# 61               Featherweight    Men
# 66                   Flyweight    Men
# 67                Bantamweight    Men
# 68  Sporting Pistol, 25 metres  Women
# 69                       Skeet  Women

# %%
total_medals_per_year = country_event_recent_df.groupby('year')['medal'].count()

import matplotlib.pyplot as plt

# Create the line plot
plt.figure(figsize=(12, 6))
total_medals_per_year.plot(marker='o')

# Customize the plot
plt.title('Total Medals Awarded Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.grid(True)
plt.show()

# %%
import pandas as pd

data_2016 = country_event_recent_df[country_event_recent_df['year'] == 2016]
data_2020 = country_event_recent_df[country_event_recent_df['year'] == 2020]

total_medals_2016 = data_2016['medal'].count()
total_medals_2020 = data_2016['medal'].count()

import matplotlib.pyplot as plt

# Create a list of years and corresponding medal counts
years = [2016, 2020]
medals = [total_medals_2016, total_medals_2020]

# Create the bar chart
plt.bar(years, medals)

# Set X/Y Limits
plt.ylim(0, 3000)


# Customize the plot
plt.title('Total Medals Awarded in the Last Two Olympic Years')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.xticks(years)
plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
df_2004 = df[df['Year'] == 2004]
df_2024 = df[df['Year'] == 2024]
# Out:
# Empty DataFrame
# Columns: [edition, edition_id, noc, sport, event, result_id, athlete, athlete_id, pos, medal, isTeamSport, year, season, country, Event, Gender]
# Index: []

# %%
country_event_recent_df.Gender.value_counts()
# Out:
# Gender
# Men      6822
# Women    6039
# Mixed     526
# Open      310
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the gender counts
gender_counts = country_event_recent_df.Gender.value_counts()

# Create a donut chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
plt.title('Gender Distribution')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

grouped_data = country_event_recent_df.groupby(['Gender', 'year', 'medal']).size().reset_index(name='count')

pivoted_data = grouped_data.pivot_table(index=['year', 'medal'], columns='Gender', values='count', fill_value=0)


# Set up the figure and axes
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the bars for each gender
pivoted_data.head(10).plot(kind='bar', ax=ax, color = ["red", "green", "yellow", "blue"])

# Customize the plot
plt.title('Female vs. Male Medal Wins by Year and Medal Type')
plt.xlabel('Year and Medal Type')
plt.ylabel('Number of Medals')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
import matplotlib.pyplot as plt

gold_medals = country_event_recent_df[country_event_recent_df['medal'] == 'Gold']
grouped_data = gold_medals.groupby(['Gender', 'season', 'year']).size().reset_index(name='Gold Medals')


# Pivot the data for easier plotting
pivoted_data = grouped_data.pivot_table(index=['year', 'season'], columns='Gender', values='Gold Medals', fill_value=0)


# Create the bar chart
pivoted_data.head(10).plot(kind='bar', figsize=(15, 8), color = ["green", "yellow", "red", "blue"])
plt.title('Gold Medals by Gender and Season')
plt.xlabel('Year and Season')
plt.ylabel('Number of Gold Medals')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
female_mask_s = country_event_recent_df['Gender'] == 'Women'
female_country_event_recent_df = country_event_recent_df[female_mask_s]
print(female_country_event_recent_df.shape)
female_country_event_recent_df.head()
# Out:
# (6039, 16)
#                  edition  edition_id  noc      sport  \
# 55  2012 Summer Olympics          54  BRN  Athletics
# 56  2016 Summer Olympics          59  BRN  Athletics
# 57  2016 Summer Olympics          59  BRN  Athletics
# 58  2020 Summer Olympics          61  BRN  Athletics
# 68  2004 Summer Olympics          26  AZE   Shooting
#
#                                 event  result_id             athlete  \
# 55                1,500 metres, Women     302391        Maryam Jamal
# 56                    Marathon, Women     359066        Eunice Kirwa
# 57   3,000 metres Steeplechase, Women     359093          Ruth Jebet
# 58               10,000 metres, Women   19000739  Kalkidan Gezahegne
# 68  Sporting Pistol, 25 metres, Women      52023       İradə Aşumova
#
#     athlete_id pos   medal  isTeamSport  year           season     country  \
# 55      115219   1    Gold        False  2012  Summer Olympics     Bahrain
# 56      129369   2  Silver        False  2016  Summer Olympics     Bahrain
# 57      129374   1    Gold        False  2016  Summer Olympics     Bahrain
# 58      141289   2  Silver        False  2020  Summer Olympics     Bahrain
# 68       41255   3  Bronze        False  2004  Summer Olympics  Azerbaijan
#
#                          Event Gender
# 55                1,500 metres  Women
# 56                    Marathon  Women
# 57   3,000 metres Steeplechase  Women
# 58               10,000 metres  Women
# 68  Sporting Pistol, 25 metres  Women

# %%
## Filter for Summer and Winter Olympics
#female_summer_olympics_df = female_country_event_recent_df[female_country_event_recent_df['edition'].str.contains('Summer Olympics')]
#female_winter_olympics_df = female_country_event_recent_df[female_country_event_recent_df['edition'].str.contains('Winter Olympics')]
#print(female_summer_olympics_df.shape)
#print(female_winter_olympics_df.shape)

# %%
#print(female_summer_olympics_df.info())
#print(female_winter_olympics_df.info())

# %%
#female_summer_olympics_df.head(3)

# %%
#female_winter_olympics_df.head(3)

# %%
female_data = female_country_event_recent_df
grouped_data = female_data.groupby(['year', 'season']).size().reset_index(name='Female Participants')


# Pivot the data for easier plotting
pivoted_data = grouped_data.pivot_table(index='year', columns='season', values='Female Participants', fill_value=0)

# Create the line plot
pivoted_data.plot(figsize=(12, 6))
plt.title('Female Participation in the Olympics Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Female Participants')
plt.legend(title='Season')
plt.show()

# %%
female_country_event_recent_df['medal'].value_counts()
# Out:
# medal
# Bronze    2058
# Gold      1999
# Silver    1982
# Name: count, dtype: int64

# %%
female_country_event_recent_df['medal'].value_counts().index
# Out:
# Index(['Bronze', 'Gold', 'Silver'], dtype='object', name='medal')

# %%
female_country_event_recent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6039 entries, 55 to 44686
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   edition      6039 non-null   object
#  1   edition_id   6039 non-null   int64
#  2   noc          6039 non-null   object
#  3   sport        6039 non-null   object
#  4   event        6039 non-null   object
#  5   result_id    6039 non-null   int64
#  6   athlete      6039 non-null   object
#  7   athlete_id   6039 non-null   int64
#  8   pos          6039 non-null   object
#  9   medal        6039 non-null   object
#  10  isTeamSport  6039 non-null   bool
#  11  year         6039 non-null   int64
#  12  season       6039 non-null   object
#  13  country      6039 non-null   object
#  14  Event        6039 non-null   object
#  15  Gender       6039 non-null   object
# dtypes: bool(1), int64(4), object(11)
# memory usage: 760.8+ KB

# %%
female_country_event_recent_df.describe()
# Out:
#         edition_id     result_id    athlete_id         year
# count  6039.000000  6.039000e+03  6.039000e+03  6039.000000
# mean     52.446432  4.897997e+06  1.472210e+05  2012.778937
# std      11.582262  7.814463e+06  2.304139e+05     5.773118
# min      26.000000  2.600000e+01  2.480000e+02  2004.000000
# 25%      53.000000  2.600500e+05  1.077225e+05  2008.000000
# 50%      57.000000  3.500880e+05  1.187680e+05  2012.000000
# 75%      60.000000  9.000700e+06  1.301630e+05  2018.000000
# max      62.000000  1.902080e+07  2.506221e+06  2022.000000

# %%
medals_per_country = female_country_event_recent_df.groupby('country')['medal'].count().sort_values(ascending=False)
medals_per_country.head(10)
# Out:
# country
# United States                 969
# People's Republic of China    462
# Russian Federation            436
# Canada                        398
# Germany                       320
# Australia                     302
# Netherlands                   275
# Japan                         249
# Great Britain                 225
# France                        183
# Name: medal, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
medals_per_country = country_event_recent_df.groupby('country')['medal'].count().sort_values(ascending=False)

medals_per_country.head(10).plot(kind='bar', figsize=(10, 6))
plt.title('Medals per Country')
plt.xlabel('Country')
plt.ylabel('Number of Medals')
plt.show()

# %%
medals_per_year = country_event_recent_df.groupby('year')['medal'].count()
medals_per_year.head(10)
# Out:
# year
# 2004    2054
# 2006     535
# 2008    2080
# 2010     534
# 2012    1983
# 2014     615
# 2016    2063
# 2018     673
# 2020    2434
# 2022     726
# Name: medal, dtype: int64

# %%
medals_per_year = country_event_recent_df.groupby('year')['medal'].count()

medals_per_year.head(12).plot(kind='bar', figsize=(10, 6), color=["blue", "green"])
plt.title('Medals per Year')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.show()

# %%
# Create the line plot
plt.figure(figsize=(12, 6))
medals_per_year.plot(marker='o')

# Customize the plot
plt.title('Medal Count Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_10_countries = country_event_recent_df.groupby('country')['medal'].count().nlargest(10).index
filtered_df = country_event_recent_df[country_event_recent_df['country'].isin(top_10_countries)]
grouped_data = filtered_df.groupby(['country', 'Gender', 'season', 'medal']).size().reset_index(name='Medal Count')

# Pivot the data for easier plotting
pivoted_data = grouped_data.pivot_table(index=['country', 'season'], columns=['Gender', 'medal'], values='Medal Count', fill_value=0)

# Create the grouped bar chart
pivoted_data.plot(kind='bar', figsize=(15, 8))
plt.title('Medal Distribution by Country, Gender, and Season')
plt.xlabel('Country and Season')
plt.ylabel('Number of Medals')
plt.xticks(rotation=45)
plt.legend(title='Gender and Medal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
country_event_recent_df


# Pivot table to group data by event and year
medal_counts = country_event_recent_df.pivot_table(index='event', columns='year', values='medal', aggfunc='count')

# Create a stacked bar chart
medal_counts.head(20).plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Medal Counts by Event and Year')
plt.xlabel('Event')
plt.ylabel('Number of Medals')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
#mask = female_summer_olympics_df.medal == "Gold"
#Gold_female_summer_olympics_df = female_summer_olympics_df.loc[mask]
#print(Gold_female_summer_olympics_df.shape)
#Gold_female_summer_olympics_df.head()

# %%
#Gold_female_summer_olympics_df["event"].values

# %%
#Gold_female_summer_olympics_df["country"].values

# %%
def get_medal_color_df(df, color):
    if color not in MEDAL_TYPES:
        raise ValueError(f"Invalid medal type {color}")

    mask = df.medal == color
    color_df = df.loc[mask]
    print(color_df.shape)
    return color_df

# %%
#female_gold_df = get_medal_color_df(female_country_event_recent_df, 'Gold')
get_medal_color_df(female_country_event_recent_df, 'Gold').head(3)
# Out:
# (1999, 16)
#                   edition  edition_id  noc      sport  \
# 55   2012 Summer Olympics          54  BRN  Athletics
# 57   2016 Summer Olympics          59  BRN  Athletics
# 139  2020 Summer Olympics          61  BER  Triathlon
#
#                                 event  result_id       athlete  athlete_id  \
# 55                1,500 metres, Women     302391  Maryam Jamal      115219
# 57   3,000 metres Steeplechase, Women     359093    Ruth Jebet      129374
# 139           Olympic Distance, Women   18000699   Flora Duffy      116209
#
#     pos medal  isTeamSport  year           season  country  \
# 55    1  Gold        False  2012  Summer Olympics  Bahrain
# 57    1  Gold        False  2016  Summer Olympics  Bahrain
# 139   1  Gold        False  2020  Summer Olympics  Bermuda
#
#                          Event Gender
# 55                1,500 metres  Women
# 57   3,000 metres Steeplechase  Women
# 139           Olympic Distance  Women

# %%
gold_medals = female_country_event_recent_df[female_country_event_recent_df['medal'] == 'Gold'].groupby('country')['medal'].count().sort_values(ascending=False)
top_10_gold = gold_medals.head(10)
top_10_gold
# Out:
# country
# United States                 432
# People's Republic of China    182
# Russian Federation            166
# Canada                        151
# Netherlands                   117
# Germany                       114
# Australia                      96
# Japan                          76
# Great Britain                  74
# Republic of Korea              57
# Name: medal, dtype: int64

# %%
# Filter for gold medals
gold_medals = country_event_recent_df[country_event_recent_df['medal'] == 'Gold']

# Group by country and count the gold medals
grouped_data = gold_medals.groupby(['country', 'Gender']).size().reset_index(name='Gold Medals')

import matplotlib.pyplot as plt

# Pivot the data for easier plotting
pivoted_data = grouped_data.pivot_table(index='country', columns='Gender', values='Gold Medals', fill_value=0)

# Get the top 10 countries based on total gold medals
top_10_countries = pivoted_data.sum(axis=1).nlargest(10).index

# Filter the pivoted data for the top 10 countries
top_10_pivoted_data = pivoted_data.loc[top_10_countries]

# Create the bar chart
top_10_pivoted_data.plot(kind='bar', figsize=(15, 8))
plt.title('Top 10 Countries by Gold Medals (Male vs. Female)')
plt.xlabel('Country')
plt.ylabel('Number of Gold Medals')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# Filter for silver medals
silver_medals = country_event_recent_df[country_event_recent_df['medal'] == 'Silver']

# Group by country and count the gold medals
grouped_data = silver_medals.groupby(['country', 'Gender']).size().reset_index(name='Silver Medals')

# Pivot the data for easier plotting
pivoted_data = grouped_data.pivot_table(index='country', columns='Gender', values='Silver Medals', fill_value=0)

# Get the top 10 countries based on total gold medals
top_10_countries = pivoted_data.sum(axis=1).nlargest(10).index

# Filter the pivoted data for the top 10 countries
top_10_pivoted_data = pivoted_data.loc[top_10_countries]

# Create the bar chart
top_10_pivoted_data.plot(kind='bar', figsize=(15, 8))
plt.title('Top 10 Countries by Silver Medals (Male vs. Female)')
plt.xlabel('Country')
plt.ylabel('Number of Silver Medals')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# Filter for bronze medals
bronze_medals = country_event_recent_df[country_event_recent_df['medal'] == 'Bronze']

# Group by country and count the gold medals
grouped_data = bronze_medals.groupby(['country', 'Gender']).size().reset_index(name='Bronze Medals')

# Pivot the data for easier plotting
pivoted_data = grouped_data.pivot_table(index='country', columns='Gender', values='Bronze Medals', fill_value=0)

# Get the top 10 countries based on total gold medals
top_10_countries = pivoted_data.sum(axis=1).nlargest(10).index

# Filter the pivoted data for the top 10 countries
top_10_pivoted_data = pivoted_data.loc[top_10_countries]

# Create the bar chart
top_10_pivoted_data.plot(kind='bar', figsize=(15, 8))
plt.title('Top 10 Countries by Bronze Medals (Male vs. Female)')
plt.xlabel('Country')
plt.ylabel('Number of Bronze Medals')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
medals_by_country_year = country_event_recent_df.groupby(['country', 'year'])['medal'].count().unstack()

medals_by_country_year.plot(kind='bar', stacked=True, figsize=(15, 8))
plt.title('Medals per Country and Year')
plt.xlabel('Country')
plt.ylabel('Number of Medals')
plt.show()

# %%
 # Change Canvas Size
plt.figure(figsize=(20, 20))

# Create a basic plot
df = medals_by_country_year = female_country_event_recent_df.groupby(['country', 'year'])['medal'].count().unstack()
sns.heatmap(df, annot=True)

# Customization
plt.title("Heatmap", fontweight="bold", fontsize=16, fontfamily="Arial")

# Show/Save the Graph
plt.show()

# %%
def get_medal_count_by_country(df, color):
    count_s = get_medal_color_df(df, 'Gold').groupby('country').count().iloc[:, 0].sort_values(ascending=False)
    return count_s

# %%
def get_all_medal_counts_by_country(df):
    medal_counts_by_country = {color: get_medal_count_by_country(df, color) 
                                  for color in MEDAL_TYPES}
    return medal_counts_by_country

# %%
# Sort the countries by the number of gold medals in descending order
female_country_event_recent_df= get_all_medal_counts_by_country(female_winter_olympics_df)
female_country_event_recent_df['Gold'].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Sort the countries by the number of gold medals in descending order
# ----> 2 female_country_event_recent_df= get_all_medal_counts_by_country(female_winter_olympics_df)
#       3 female_country_event_recent_df['Gold'].head(10)
#
# NameError: name 'female_winter_olympics_df' is not defined

# %%
print(female_winter_medal_counts_by_country['Gold'].index)
print(female_winter_medal_counts_by_country['Gold'].values)

# %%
female_winter_olympics_df["sport"].head().values

# %%
female_winter_olympics_df["sport"].head().values

# %%
female_winter_olympics_df["sport"].describe()

# %%
countries = female_winter_medal_counts_by_country['Gold'].index
medals_per_country = female_winter_medal_counts_by_country['Gold'].values

# Change Canvas Size
plt.figure(figsize=(20, 10))

# Create a basic plot
plt.scatter(countries, medals_per_country , color="#9A4C95", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Countries", fontfamily="Arial", fontsize=12)
plt.ylabel("Gold Count", fontfamily="Arial", fontsize=12)
plt.title("Gold per Country", fontweight="bold", fontsize=16, fontfamily="Arial")

plt.xticks(rotation=90)

# Set X/Y Limits
plt.ylim(-1, 150)
plt.xlim(-1, 25)

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Show/Save the Graph
plt.show()
